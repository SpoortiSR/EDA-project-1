# %%
import pandas as pd

# %%
df=pd.read_csv("Documents/data.xlsx - Sheet1.csv")

# %%
df.head(10)
# Out:
#   Unnamed: 0       ID   Salary              DOJ              DOL  \
# 0      train   203097   420000  06/01/2012 0:00          present
# 1      train   579905   500000  09/01/2013 0:00          present
# 2      train   810601   325000  06/01/2014 0:00          present
# 3      train   267447  1100000  07/01/2011 0:00          present
# 4      train   343523   200000  03/01/2014 0:00  03/01/2015 0:00
# 5      train  1027655   300000  06/01/2014 0:00          present
# 6      train   947847   300000  08/01/2014 0:00  05/01/2015 0:00
# 7      train   912934   400000  07/01/2014 0:00  07/01/2015 0:00
# 8      train   552574   600000  07/01/2013 0:00          present
# 9      train  1203363   230000  07/01/2014 0:00          present
#
#                 Designation    JobCity Gender              DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f     2/19/90 0:00         84.30
# 1         assistant manager     Indore      m  10/04/1989 0:00         85.40
# ...

# %%
df.shape
# Out:
# (3998, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 39 columns):
# Unnamed: 0               3998 non-null object
# ID                       3998 non-null int64
# Salary                   3998 non-null int64
# DOJ                      3998 non-null object
# DOL                      3998 non-null object
# Designation              3998 non-null object
# JobCity                  3998 non-null object
# Gender                   3998 non-null object
# DOB                      3998 non-null object
# 10percentage             3998 non-null float64
# 10board                  3998 non-null object
# 12graduation             3998 non-null int64
# 12percentage             3998 non-null float64
# 12board                  3998 non-null object
# CollegeID                3998 non-null int64
# CollegeTier              3998 non-null int64
# Degree                   3998 non-null object
# Specialization           3998 non-null object
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# Salary                   0
# DOJ                      0
# DOL                      0
# Designation              0
# JobCity                  0
# Gender                   0
# DOB                      0
# 10percentage             0
# 10board                  0
# 12graduation             0
# 12percentage             0
# 12board                  0
# CollegeID                0
# CollegeTier              0
# Degree                   0
# Specialization           0
# collegeGPA               0
# CollegeCityID            0
# CollegeCityTier          0
# CollegeState             0
# GraduationYear           0
# English                  0
# Logical                  0
# Quant                    0
# Domain                   0
# ComputerProgramming      0
# ElectronicsAndSemicon    0
# ComputerScience          0
# MechanicalEngg           0
# ElectricalEngg           0
# TelecomEngg              0
# CivilEngg                0
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 3968    False
# 3969    False
# 3970    False
# 3971    False
# 3972    False
# 3973    False
# 3974    False
# 3975    False
# 3976    False
# 3977    False
# 3978    False
# 3979    False
# 3980    False
# 3981    False
# 3982    False
# 3983    False
# 3984    False
# 3985    False
# 3986    False
# 3987    False
# 3988    False
# 3989    False
# 3990    False
# 3991    False
# 3992    False
# 3993    False
# 3994    False
# 3995    False
# 3996    False
# 3997    False
# ...

# %%
# converting present to today,date
import datetime
today= datetime.datetime.today()

df.loc[df['DOL'] == 'present', 'DOL'] = today

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'])

# %%
df['DOL'] = pd.to_datetime(df['DOL'])

# %%
df['DOB'] = pd.to_datetime(df['DOB'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 39 columns):
# Unnamed: 0               3998 non-null object
# ID                       3998 non-null int64
# Salary                   3998 non-null int64
# DOJ                      3998 non-null datetime64[ns]
# DOL                      3998 non-null datetime64[ns]
# Designation              3998 non-null object
# JobCity                  3998 non-null object
# Gender                   3998 non-null object
# DOB                      3998 non-null datetime64[ns]
# 10percentage             3998 non-null float64
# 10board                  3998 non-null object
# 12graduation             3998 non-null int64
# 12percentage             3998 non-null float64
# 12board                  3998 non-null object
# CollegeID                3998 non-null int64
# CollegeTier              3998 non-null int64
# Degree                   3998 non-null object
# Specialization           3998 non-null object
# ...

# %%
df.describe()
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %%
# there are some columns which are not necessary in the dataframe,dropping them
df1=df.drop(['CollegeID','CollegeCityID'], axis=1)

# %%
df1.shape
# Out:
# (3998, 37)

# %%
df1['JobCity'].value_counts()
# Out:
# Bangalore              627
# -1                     461
# Noida                  368
# Hyderabad              335
# Pune                   290
# Chennai                272
# Gurgaon                198
# New Delhi              196
# Mumbai                 108
# Kolkata                 98
# Jaipur                  46
# Lucknow                 36
# Mysore                  36
# Navi Mumbai             32
# chennai                 27
# pune                    26
# Chandigarh              26
# Greater Noida           26
# Indore                  24
# Bhubaneswar             22
# Coimbatore              20
# Faridabad               18
# Bhopal                  17
# Ahmedabad               17
# hyderabad               16
# bangalore               15
# Ghaziabad               15
# Bangalore               14
# kolkata                 13
# Kochi/Cochin            13
#                       ...
# kharagpur                1
# PATNA                    1
# Nellore                  1
# ...

# %%
# jobcity is categorical column ,we will replace it with missing or unknown
df1['JobCity'] = df1['JobCity'].str.replace('-1','unknown')

# %%
cols_numerical = df1[['Salary', '10percentage', '12percentage', 'collegeGPA', 'GraduationYear', 'Quant', 'Domain', 'conscientiousness', 'agreeableness', 'extraversion', 'nueroticism', 'openess_to_experience']]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_boxplots_matplotlib(df):
    fig, axes = plt.subplots(nrows=len(df.columns), ncols=1, figsize=(10, 25))   
    for i, column in enumerate(df.columns):
        axes[i].boxplot(df[column].dropna(), vert=False)  
        axes[i].set_title(column)
    plt.tight_layout()
    plt.show()

plot_boxplots_matplotlib(cols_numerical)

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(8,6))
sns.distplot(cols_numerical ['Salary'])
plt.axvline(cols_numerical ['Salary'].mean(),color='black', label='Mean')
plt.title("Pdf distribution of Salary")
plt.legend(shadow=True,fontsize="larger")
# Out:
# C:\Users\Spoorti\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(8,6))
sns.distplot(cols_numerical ['10percentage'])
plt.axvline(cols_numerical ['10percentage'].mean(),color='black', label='Mean')
plt.title("Pdf distribution of 10percentage")
plt.legend(shadow=True,fontsize="larger")

# %%
def plot_density_with_mean(data, column_name, title):
    sns.set_style("darkgrid")
    plt.figure(figsize=(8,6))
    sns.distplot(data[column_name])
    plt.axvline(data[column_name].mean(), color='black', label='Mean')
    plt.title("Pdf distribution of " + title)
    plt.legend(shadow=True, fontsize="larger")
    plt.show()


for column in cols_numerical:
    plot_density_with_mean(df1, column, column)

# %%
#Salary':- right skewed so it implies outliers in the data
#some columns like GraduationYear, Domain, agreeableness and openees_to_experience are not normally distributed.

# %%
# checking frequency distribution ofage :
plt.figure(figsize=(8,6))
sns.countplot(df1['Gender'])
plt.show()

# %%
# there are more number of males compared to females.

# %%
designation_count = df1['Designation'].value_counts()
designation_count[:20] # top 20
# Out:
# software engineer              539
# software developer             265
# system engineer                205
# programmer analyst             139
# systems engineer               118
# java software engineer         111
# software test engineer         100
# project engineer                77
# technical support engineer      76
# senior software engineer        72
# java developer                  67
# test engineer                   57
# web developer                   54
# application developer           52
# assistant manager               52
# network engineer                51
# data analyst                    49
# business analyst                49
# engineer                        47
# associate software engineer     46
# Name: Designation, dtype: int64

# %%
plt.figure(figsize=(9,5))
plt.title("Count of Employee Specialization")
df1['Specialization'].value_counts().head(25).plot.bar()

# %%
# majority of them have done Computer engineering and  Electronics and Communications.

# %%
sns.countplot(df1['Degree'])

# %%
# majority of them have done B.E./B.Tech

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Gender', y='Salary', data=df1, ci=None)  
plt.title("Bar Plot of Gender vs Salary")
plt.xlabel("Gender")
plt.ylabel("Salary")
plt.show()

# %%
# Males have more salary  compared to females

# %%
df1.groupby(df1['Specialization']).count()['Gender']
# Out:
# Specialization
# aeronautical engineering                         3
# applied electronics and instrumentation          9
# automobile/automotive engineering                5
# biomedical engineering                           2
# biotechnology                                   15
# ceramic engineering                              1
# chemical engineering                             9
# civil engineering                               29
# computer and communication engineering           1
# computer application                           244
# computer engineering                           600
# computer networking                              1
# computer science                                 2
# computer science & engineering                 744
# computer science and technology                  6
# control and instrumentation engineering          1
# electrical and power engineering                 2
# electrical engineering                          82
# ...

# %%
fig, ax = plt.subplots(figsize=(16,6))
sns.countplot(data=df1, x='Specialization', hue='Gender')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %%
# the no of males is higher in all domain.And we can say hat majority of male and female have taken CS and EC engineering as specialization

# %%
# checking for correlation using heatmap
plt.figure(figsize=(20,15))
sns.heatmap(df1.corr() , annot=True)
plt.show()

# %%
#We can also say that the subjects English,Logical,Quant are  positively correlated with each other which means if a student get better marks in one subject then it is highly possible that he or she will get better marks in other subjects

# %%
#Bivariate analysis on Gender and collegeGPA
plt.figure(figsize=(5,2.5))
sns.barplot(y= df['Gender'],x = df['collegeGPA'],ci = None )
plt.title("collegeGPA vs Gender barplot")
plt.xlabel("collegeGPA")
plt.ylabel("GENDER")
plt.plot()
# Out:
# []

# %%
# we can say that from above graph that females have higher GPA compared to boys in college

# %%
# analysis pn degree and salary
plt.figure(figsize=(5,5))
sns.barplot(y= df1['Degree'],x = df1['Salary'],ci = None )
plt.title("Degree VS salary")
plt.xlabel("Salary")
plt.ylabel("Degree")
plt.plot()
# Out:
# []

# %%
# Students who have done Mtech/M.E. earn more compared to others

# %%
# analysis of graduation year and gender
sns.catplot(x = "GraduationYear",hue="Gender",data = df1,kind='count')
plt.xticks(rotation=90)
plt.show()

# %%
# No of people graduated in 2013 is more comparatively.

# %%
# Analysis of salary and specialization :
plt.figure(figsize=(10,35))
sns.barplot(y= df1['Specialization'],x = df1['Salary'],ci = None )
plt.title("Bar plot of Specialization,Salary of the student")
plt.xlabel("Salary")
plt.ylabel("Specialization")
plt.plot()
# Out:
# []

# %%
# students with specialization in polymer technology have highest salary.

# %%
# analysis of age and salary:

# lets calculate age:
df1['Age'] = ((df1['DOL'] - df1['DOB']).map(lambda x: round(x.days/365)))

plt.figure(figsize=(9,5))
plt.title('Age Vs Salary')
sns.barplot(x='Age',y='Salary',data=df1);
# Out:
# C:\Users\Spoorti\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# age group 38-39 has more salary compared to others.

# %%
plt.figure(figsize=(9,5))
df1['Age'].value_counts().plot(kind='bar')
plt.title("Count of Employee Age")
plt.xticks(rotation=0);

# %%
#large number of employees are from 24,23,32,33,22,25

# %%
# RESEARCH QUESTION -HYPOTHESIS:
#Is there a relationship between gender and specialisation? (i.e. Does the preference of Specialisation depend on the Gender?)

# %%
df1['Gender'].unique()
# Out:
# array(['f', 'm'], dtype=object)

# %%
observed=pd.crosstab(df1['Specialization'], df1['Gender'], margins=True)

# %%
fig, ax = plt.subplots(figsize=(16,6))
sns.countplot(data=df1, x='Specialization', hue='Gender')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %%
#We can say male and female ratio with respect to specialization column, number of male ratio is higher in every domain. if you observe both male and female are choosing  computer science and electronics groups

# %%
# the hypothesis is false

# %%
df1['exp'] = pd.to_datetime(df1["DOL"]).dt.year - pd.to_datetime(df1['DOJ']).dt.year

# %%
df1.head()
# Out:
#   Unnamed: 0      ID   Salary        DOJ                        DOL  \
# 0      train  203097   420000 2012-06-01 2024-02-22 22:25:32.161907
# 1      train  579905   500000 2013-09-01 2024-02-22 22:25:32.161907
# 2      train  810601   325000 2014-06-01 2024-02-22 22:25:32.161907
# 3      train  267447  1100000 2011-07-01 2024-02-22 22:25:32.161907
# 4      train  343523   200000 2014-03-01 2015-03-01 00:00:00.000000
#
#                 Designation    JobCity Gender        DOB  10percentage ...  \
# 0   senior quality engineer  Bangalore      f 1990-02-19          84.3 ...
# 1         assistant manager     Indore      m 1989-10-04          85.4 ...
# 2          systems engineer    Chennai      f 1992-08-03          85.0 ...
# 3  senior software engineer    Gurgaon      m 1989-12-05          85.6 ...
# 4                       get    Manesar      m 1991-02-27          78.0 ...
#
#   ElectricalEngg  TelecomEngg  CivilEngg conscientiousness  agreeableness  \
# ...

# %%
new=df1[(df1["Designation"].isin(["programmer analyst","software engineer","hardware engineer","associate engineer"])) & (df1["exp"]==0)]
plt.figure(figsize=(10,5))
sns.barplot(x="Designation",y="Salary",hue="Gender",data=new)
# Out:
# C:\Users\Spoorti\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from scipy import stats as st
from scipy.stats import chi2_contingency as cst
pv = st.ttest_1samp(new['Salary'],popmean=250000)[1]
#p- value should be >0.05 to claim the null hypothesis
if pv < 0.05:
    print('We reject the null hypothesis and Average salary is not equal to 250000')
else:
    print('We fail to reject null hypothesis and Avergae salary is equal to 250000')
# Out:
# We fail to reject null hypothesis and Avergae salary is equal to 250000

# %%
# the pypothesis is wrong ,we reject it.

# %%
sample_columns = pd.crosstab(df1['Gender'],df1['Specialization'],margins=True)
pv = cst(sample_columns)[1]
if pv < 0.05:
    print('We accept  the null hypothesis and Gender impacts specialization')
else:
    print('We  reject null hypothesis and Gender does not impact specialization')
# Out:
# We  reject null hypothesis and Gender does not impact specialization

# %%
# gender does not impact specialization .
